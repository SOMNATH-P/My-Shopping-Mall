# %%
print("***************Welcome to the my fasion shop**************")
print("\nWe are happy to see you here")

a = [1,2,3,4]


#while a==yes:
    
print(">>>>>>>>>>>>>> We Have Three Categories")
print("Select 1 for Mens Section")
print("Select 2 for Womens Section")
print("Select 3 for Kids Section")


#men's Section

slMJ = []#select mens jeans
slMTS = []#select mens T-shirt
slMS = []#setect mens shirt
slMSw = []#select mens sweater

MJ = 0
MTS = 0
MS = 0
MSw= 0

#woman's Section       
slWS = []#select womens sadi
slWTS = []#select womens T-shirts
slWK = []#select womens kurta
slWSw = []#select womens Sweaters

WS = 0
WTS = 0
WK = 0
WSw = 0

#Kid's Section
slKJ = []
slKTS = []
slKS = []
slKSw = []

KJ = 0
KTS = 0
KS = 0
KSw = 0

#Mens started
opt = int(input("selected option: "))
if opt==1:
    print("Mens Section")
    print("Select 1 for Jeans")
    print("Select 2 for T_Shirts")
    print("Select 3 for Shirts")
    print("Select 4 for Sweaters")
    shopping_list_Mens = {}
    shopping_list_Mens_Jeans = {}
    shopping_list_Mens_T_Shirts = {}
    shopping_list_Mens_Shirts = {}
    shopping_list_Mens_Sweaters = {}
    

    cat = int(input("what would you like to buy Today: "))
    if cat==1:
        cost = 700
        print("Jeans Rs.{0}".format(cost))
        n = int(input("Enter no. of pieces: "))
        Bill = cost*n
        print(Bill)
        shopping_list_Mens_Jeans["Section"] = "Men"
        shopping_list_Mens_Jeans["Item"] = "Jeans"
        shopping_list_Mens_Jeans["Quantity"] = n 
        shopping_list_Mens_Jeans["Cost"] = Bill

        slMJ  = list(shopping_list_Mens_Jeans.values())
        cat = int(input("Do you want to continue:"))
        

       
    elif cat==2:
        cost = 400
        print("T_Shirts Rs.{0}".format(cost))
        n = int(input("Enter no. of pieces: "))
        Bill = cost*n
        print(Bill)
        shopping_list_Mens_T_Shirts["Section"] = "Men"
        shopping_list_Mens_T_Shirts["Item"] = "T_Shirts"
        shopping_list_Mens_T_Shirts["Quantity"] = n
        shopping_list_Mens_T_Shirts["Cost"] = Bill

        slMTS  = list(shopping_list_Mens_T_Shirts.values())
        cat = int(input("Do you want to continue:"))

        


    elif cat==3:
        cost = 500
        print("Shirts Rs.{0}".format(cost))
        n = int(input("Enter no. of pieces: "))
        Bill = cost*n
        print(Bill)
        shopping_list_Mens_Shirts["Section"] = "Men"
        shopping_list_Mens_Shirts["Item"] = "Shirts"
        shopping_list_Mens_Shirts["Quantity"] = n
        shopping_list_Mens_Shirts["Cost"] = Bill
        
        slMS  = list(shopping_list_Mens_Shirts.values())
        cat = int(input("Do you want to continue:"))

        


    else:
        cost = 900
        print("Sweaters Rs.{0}".format(cost))
        n = int(input("Enter no. of pieces: "))
        Bill = cost*n
        print(Bill)
        shopping_list_Mens_Sweaters["Section"] = "Men"
        shopping_list_Mens_Sweaters["Item"] = "Sweaters"
        shopping_list_Mens_Sweaters["Quantity"] = n
        shopping_list_Mens_Sweaters["Cost"] = Bill
        
        slMS  = list(shopping_list_Mens_Shirts.values())
        cat = int(input("Do you want to continue:"))

        
#womens started       
elif opt==2:
    print("Womens Section")
    print("Select 1 for Sadi")
    print("Select 2 for T_Shirts")
    print("Select 3 for Kurta")
    print("Select 4 for Sweaters")
    
    shopping_list_Womens = {}
    shopping_list_Womens_Sadi = {}
    shopping_list_Womens_T_Shirts = {}
    shopping_list_Womens_Kurta = {}
    shopping_list_Womens_Sweaters = {}
    

    cat = str(input("what would you like to buy Today: "))
    if cat==1:
        cost = 1000
        print("Sadi Rs.{0}".format(cost))
        n = int(input("Enter no. of pieces: "))
        Bill = cost*n
        print(Bill)
        
        shopping_list_Womens_Sadi["Section"] = "Womens"
        shopping_list_Womens_Sadi["Item"] = "Sadi"
        shopping_list_Womens_Sadi["Quantity"] = n
        shopping_list_Womens_Sadi["Cost"] = Bill
        slWS  = list(shopping_list_Womens_Sadi.values())
        cat = int(input("Do you want to continue:"))

        
        

    elif cat==2:
        cost = 400
        print("T_Shirts Rs.{0}".format(cost))
        n = int(input("Enter no. of pieces: "))
        Bill = cost*n
        print(Bill)
        shopping_list_Womens_T_Shirts["Section"] = "Womens"
        shopping_list_Womens_T_Shirts["Item"] = "T_Shirts"
        shopping_list_Womens_T_Shirts["Quantity"] = n
        shopping_list_Womens_T_Shirts["Cost"] = Bill
        slWTS  = list(shopping_list_Mens_T_Shirts.values())
        cat = int(input("Do you want to continue:"))


        
    elif cat==3:
        cost = 700
        print("Kurta Rs.{0}".format(cost))
        n = int(input("Enter no. of pieces: "))
        Bill = cost*n
        print(Bill)
        shopping_list_Womens_Kurta["Section"] = "Womens"
        shopping_list_Womens_Kurta["Item"] = "Kurta"
        shopping_list_Womens_Kurta["Quantity"] = n
        shopping_list_Womens_Kurta["Cost"] = Bill
        slWk  = list(shopping_list_Womens_Kurta.values())
        cat = int(input("Do you want to continue:"))

        

        
    else:
        cost = 900
        print("Sweaters Rs.{0}".format(cost))
        n = int(input("Enter no. of pieces: "))
        Bill = cost*n
        print(Bill)
        shopping_list_Womens_Sweaters["Section"] = "Womens"
        shopping_list_Womens_Sweaters["Item"] = "Sweaters"
        shopping_list_Womens_Sweaters["Quantity"] = n
        shopping_list_Womens_Sweaters["Cost"] = Bill
        slWSw  = list(shopping_list_Womens_Sweaters.values())
        cat = int(input("Do you want to continue:"))

        

 #Kids started

else:
    print("Kids Section")
    print("Select 1 for Jeans")
    print("Select 2 for T-Shirts")
    print("Select 3 for Shirts")
    print("Select 4 for Sweaters")
    
    shopping_list_Kids = {}
    shopping_list_Kids_Jeans = {}
    shopping_list_Kids_T_Shirts = {}
    shopping_list_Kids_Shirts = {}
    shopping_list_Kids_Sweaters = {}
    
    cat = int(input("what would you like to buy Today: "))
    if cat==1:
        cost = 700
        print("Jeans Rs.{0}".format(cost))
        n = int(input("Enter no. of pieces: "))
        Bill = cost*n
        print(Bill)
        shopping_list_Kids_Jeans["Section"] = "Kids"
        shopping_list_Kids_Jeans["Item"] = "Jeans"
        shopping_list_Kids_Jeans["Quantity"] = n
        shopping_list_Kids_Jeans["Cost"] = Bill
        slKJ  = list(shopping_list_Kids_Jeans.values())
        cat = int(input("Do you want to continue:"))

        

    elif cat==2:
        cost = 400
        print("T_Shirts Rs.{0}".format(cost))
        n = int(input("Enter no. of pieces: "))
        Bill = cost*n
        print(Bill)
        shopping_list_Kids_T_Shirts["Section"] = "Kids"
        shopping_list_Kids_T_Shirts["Item"] = "T_Shirts"
        shopping_list_Kids_T_Shirts["Quantity"] = n
        shopping_list_Kids_T_Shirts["Cost"] = Bill
        slKTS  = list(shopping_list_Kids_T_Shirts.values())
        cat = int(input("Do you want to continue:"))

        

    elif cat==3:
        cost = 500
        print("Shirts Rs.{0}".format(cost))
        n = int(input("Enter no. of pieces: "))
        Bill = cost*n
        print(Bill)
        shopping_list_Kids_Shirts["Section"] = "Kids"
        shopping_list_Kids_Shirts["Item"] = "Shirts"
        shopping_list_Kids_Shirts["Quantity"] = n
        shopping_list_Kids_Shirts["Cost"] = Bill
        slKS  = list(shopping_list_Kids_Shirts.values())
        cat = int(input("Do you want to continue:"))

        


    else:
        cost = 900
        print("Sweaters Rs.{0}".format(cost))
        n = int(input("Enter no. of pieces: "))
        Bill = cost*n
        print(Bill)
        shopping_list_Kids_Sweaters["Section"] = "Kids"
        shopping_list_Kids_Sweaters["Item"] = "Sweaters"
        shopping_list_Kids_Sweaters["Quantity"] = n
        shopping_list_Kids_Sweaters["Cost"] = Bill
        slKSw  = list(shopping_list_Kids_Sweaters.values())
        cat = int(input("Do you want to continue:"))

        

        
  
#define total count
        
def TC(MJ=0, MTS=0, MS=0, MSw=0, WS=0, WTS=0, WK=0, WSw=0, KJ=0, KTS=0, KS=0, KSw=0):

#mens:

    if len(slMJ) > 0:
        MJ = slMJ[3]
    if len(slMTS) > 0:
        MTS = slMTS[3]
    if len(slMS) > 0:
        MS = slMS[3]
    if len(slMSw) > 0:
        MSw = slMSw[3]
#womens:

    if len(slWS) > 0:
        WS = slWS[3]
    if len(slWTS) > 0:
        WTS = slWTS[3]
    if len(slWK) > 0:
        WK = slWK[3]
    if len(slWSw) > 0:
        WSw = slWSw[3]
#Kids:

    if len(slKJ) > 0:
        KJ = slKJ[3]
    if len(slKTS) > 0:
        KTS = slKTS[3]
    if len(slKS) > 0:
        KS = slKS[3]
    if len(slKSw) > 0:
        KSw = slKSw[3]

    return (MJ + MTS + MS + MSw + WS + WTS + WK + WSw + KJ + KTS + KS + KSw)


TOTAL_COST = TC(MJ, MTS, MS, MSw, WS, WTS, WK, WSw, KJ, KTS, KS, KSw)


def Discount(Bill_Amount = TOTAL_COST):

    if Bill_Amount <= 10000:
        Discount = Bill_Amount * 0.10
        final_bill = Bill_Amount - Discount
    elif (Bill_Amount >= 10000 and Bill_Amount <= 20000):
        Discount = Bill_Amount * 0.25
        final_bill = Bill_Amount - Discount
    elif (Bill_Amount >= 20000 and Bill_Amount <= 25000):
        Discount = Bill_Amount * 0.30
        final_bill = Bill_Amount - Discount
    else:
        Discount = Bill_Amount * 0.15
        final_bill = Bill_Amount - Discount

    return final_bill

print("**********************  MY FASHION SUPER MART  ****************************")
print("SECTION  ITEM  QTY     TOTAL_COST")

#Mens
if len(slMJ) > 0:
    for i in slMJ:
        print(i, end="    ")
    print("")
    
if len(slMTS) > 0:
    for i in slMTS:
        print(i, end="    ")
    print("")
    
if len(slMS) > 0:
    for i in slMS:
        print(i, end="    ")
    print("")


if len(slMSw) > 0:
    for i in slMSw:
        print(i, end="    ")
    print("")

#womens

if len(slWS) > 0:
    for i in slWS:
        print(i, end="    ")
    print("")
    
if len(slWTS) > 0:
    for i in slWTS:
        print(i, end="    ")
    print("")
    
if len(slWK) > 0:
    for i in slWK:
        print(i, end="    ")
    print("")
    
if len(slWSw) > 0:
    for i in slWSw:
        print(i, end="    ")
    print("")

#Kids
if len(slKJ) > 0:
    for i in slKJ:
        print(i, end="    ")
    print("")
    
if len(slKTS) > 0:
    for i in slKTS:
        print(i, end="    ")
    print("")
    
if len(slKS) > 0:
    for i in slKS:
        print(i, end="    ")
    print("")
    
if len(slKSw) > 0:
    for i in slKSw:
        print(i, end="    ")
    print("")


print("-------------------------------------------------------------------------------------------------------------")

print("                Total : "+str(TOTAL_COST))
Amount_with_Discount = Discount()
print("Amount_with_Discount : " + str(Amount_with_Discount))

print("-------------------------------------------------------------------------------------------------------------")

TC_with_GST = Amount_with_Discount*(1+0.25)
tax = TC_with_GST - Amount_with_Discount
print("                TAX : "+str(tax))
print("  TOTAL COST WITH GST : "+str(TC_with_GST))

print("-------------------------------------------------------------------------------------------------------------")
# Out:
# ***************Welcome to the my fasion shop**************
#
# We are happy to see you here
# >>>>>>>>>>>>>> We Have Three Categories
# Select 1 for Mens Section
# Select 2 for Womens Section
# Select 3 for Kids Section
# selected option: 1
# Mens Section
# Select 1 for Jeans
# Select 2 for T_Shirts
# Select 3 for Shirts
# Select 4 for Sweaters
# what would you like to buy Today: 2
# T_Shirts Rs.400
# Enter no. of pieces: 60
# 24000
# Do you want to continue:2
# **********************  MY FASHION SUPER MART  ****************************
# SECTION  ITEM  QTY     TOTAL_COST
# Men    T_Shirts    60    24000
# -------------------------------------------------------------------------------------------------------------
#                 Total : 24000
# Amount_with_Discount : 16800.0
# -------------------------------------------------------------------------------------------------------------
#                 TAX : 4200.0
#   TOTAL COST WITH GST : 21000.0
# ...
